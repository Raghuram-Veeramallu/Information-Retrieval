# %%
import pandas as pd

# %%
df = pd.read_csv("inverted_list.csv")
df.set_index('Words', inplace=True)

# %%
df.head()
# Out:
#         Inverted Index   Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# Words
# one                   1         2.0        13.0        14.0        15.0
# wish                 32         1.0         4.0        16.0        50.0
# dark                  1         3.0         7.0         8.0        48.0
# tree                  1         2.0         3.0         5.0         6.0
# old                   1         2.0        34.0        38.0        13.0
#
#        Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# Words
# one          16.0        19.0        22.0        23.0         24.0
# wish          NaN         NaN         NaN         NaN          NaN
# dark          NaN         NaN         NaN         NaN          NaN
# tree         10.0        12.0        16.0        18.0         20.0
# old          14.0        47.0        50.0        23.0          NaN
#
#           ...       Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# Words     ...
# ...
